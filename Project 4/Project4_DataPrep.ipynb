# %% [markdown]
# ## Data Prep

# %%
import json
import numpy as np
import pandas as pd

import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

from textblob import TextBlob
# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
# logging for gensim (set to INFO)
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)


import preprocessor as p # 
import string # use string.punctuation to clean out punctuation

from pprint import pprint

from datetime import datetime
import pickle



from tqdm import tqdm

pd.set_option('display.max_colwidth', -1)

# %%
# Export the MongoDB collection to json format and transfer from AWS EC2 to localhost
# mongoexport -d climatechange -c climate_tweets -o tweets.json
# scp myaws:tweets.json .
# Read the data into an array

tweets_data = []
tweets_file = open('tweets.json','r')
for line in tweets_file:

    tweet = json.loads(line)
    tweets_data.append(tweet)

# %%
print(len(tweets_data))
# Out:
# 17579

# %% [markdown]
# ### Load Tweets into a DataFrame

# %%
tweetsDF = pd.DataFrame()
tweetsDF['user'] = [tweet['user']['screen_name'] for tweet in tweets_data]
tweetsDF['created_at'] = [datetime.strptime(tweet['created_at'], '%a %b %d %H:%M:%S %z %Y') for tweet in tweets_data]

# %%
text = []

for tweet in tqdm(tweets_data):
    try: 
        text.append(tweet['retweeted_status']['full_text'])
    except KeyError:       
        text.append(tweet['full_text'])
        
tweetsDF['full_text'] = text
# Out:
# 100%|██████████| 17579/17579 [00:00<00:00, 733495.19it/s]

# %%
tweetsDF['truncated'] = [tweet['truncated'] for tweet in tweets_data]
tweetsDF['contains_url'] = tweetsDF['full_text'].str.contains('https', regex=True)*1
tweetsDF['favorite_count'] = [tweet['favorite_count'] for tweet in tweets_data]
tweetsDF['location'] = [tweet['place']['country'] if tweet['place'] != None else None 
                        for tweet in tweets_data]
tweetsDF['time_zone'] = [tweet['user']['time_zone'] for tweet in tweets_data]
tweetsDF['following_count'] = [tweet['user']['friends_count'] for tweet in tweets_data]
tweetsDF['followers_count'] = [tweet['user']['followers_count'] for tweet in tweets_data]
tweetsDF['retweet_count'] = [tweet['retweet_count'] for tweet in tweets_data]

# %%
tweetsDF.dtypes
# Out:
# user               object
# created_at         datetime64[ns, UTC]
# full_text          object
# truncated          bool
# contains_url       int64
# favorite_count     int64
# location           object
# time_zone          object
# following_count    int64
# followers_count    int64
# retweet_count      int64
# dtype: object

# %% [markdown]
# ## Clean Tweets

# %%
tweetsDF.full_text.replace(regex=True, inplace = True, to_replace = r'#', value = r'') # Remove #-signs, but keep words from hashtag

# %%
cleaned_tweets = []

for tweet in tweetsDF.full_text:
    cleaned_tweets.append(p.clean(tweet))
    
tweetsDF['full_text'] = cleaned_tweets

# %%
tweetsDF.full_text.replace(regex=True, inplace = True, to_replace = r'&amp;', value = r'and') # Remove ampersand code

# %%
tweets = []
for tweet in tweetsDF.full_text:
    letters_only = re.sub("[^a-zA-Z]", " ", tweet) 
    words = ' '.join(letters_only.lower().split())
    tweets.append(words)
tweetsDF['full_text'] = tweets

# %% [markdown]
# ## Sentiment Analysis

# %%
bloblist = []

for tweet in tweetsDF.full_text:
    blob = TextBlob(tweet)
    bloblist.append(blob)

# %%
sentlist = []
for blob in bloblist:
    bs = blob.sentiment
    sentlist.append(bs)

sentDF = pd.DataFrame()
sentDF['sentiment'] = sentlist

# %%
sentDF = sentDF.sentiment.apply(pd.Series)
sentDF.rename(columns={0: 'polarity', 1: 'subjectivity'}, inplace=True)
print(sentDF.polarity.mean())
print(sentDF.subjectivity.mean())
# Out:
# 0.04950138866188848
# 0.3255819384331037

# %%
tweetsDF['Polarity'] = sentDF.polarity
tweetsDF['Subjectivity'] = sentDF.subjectivity

# %%
tweetsDF
# Out:
#                   user                created_at  \
# 0      MartinKACrook   2018-02-28 22:32:24+00:00
# 1      AggieHJ         2018-02-28 22:32:06+00:00
# 2      MadonnaMadsen   2018-02-28 22:32:00+00:00
# 3      hackneywick     2018-02-28 22:31:58+00:00
# 4      ONGYEWKHOON5    2018-02-28 22:31:19+00:00
# 5      munkihanger     2018-02-28 22:31:16+00:00
# 6      tlane04         2018-02-28 22:30:31+00:00
# 7      rcjhawk86       2018-02-28 22:29:50+00:00
# 8      bestdoxiemom    2018-02-28 22:29:47+00:00
# 9      yergnflergn     2018-02-28 22:29:34+00:00
# 10     Jerzygma        2018-02-28 22:29:13+00:00
# 11     Rythmol81       2018-02-28 22:28:48+00:00
# 12     chipps_timothy  2018-02-28 22:27:56+00:00
# 13     dakotafred59    2018-02-28 22:27:55+00:00
# 14     Cielo10131      2018-02-28 22:27:18+00:00
# 15     f_talmon        2018-02-28 22:27:11+00:00
# 16     semodu_ag       2018-02-28 22:27:11+00:00
# 17     semodu_pr       2018-02-28 22:27:11+00:00
# 18     alcgunn         2018-02-28 22:26:51+00:00
# 19     Buharisnk       2018-02-28 22:26:40+00:00
# 20     CircleReader    2018-02-28 22:25:03+00:00
# 21     ckkaufmannsvcs  2018-02-28 22:23:57+00:00
# 22     LwangaMundo     2018-02-28 22:23:57+00:00
# 23     TodayInitiative 2018-02-28 22:23:01+00:00
# 24     Yubbie007       2018-02-28 22:22:33+00:00
# 25     TiaKinay        2018-02-28 22:22:09+00:00
# 26     csmonitor       2018-02-28 22:21:11+00:00
# 27     ParulHumanRight 2018-02-28 22:20:42+00:00
# 28     Climatevision   2018-02-28 22:20:30+00:00
# 29     MikeMcG71253439 2018-02-28 22:20:18+00:00
# ...                ...                       ...
# 17549  futureofclimate 2018-02-19 03:25:00+00:00
# 17550  CargillCountry  2018-02-19 03:20:42+00:00
# 17551  350Triangle     2018-02-19 03:11:24+00:00
# 17552  Dennyontheblock 2018-02-19 03:07:51+00:00
# 17553  ArunNirmal_     2018-02-19 03:03:59+00:00
# 17554  IPCCisstupid    2018-02-19 02:38:22+00:00
# 17555  LedgicPSN       2018-02-19 02:28:23+00:00
# 17556  truthdetector15 2018-02-19 02:19:49+00:00
# 17557  MikaeylaChetty  2018-02-19 02:10:08+00:00
# 17558  LACiAlfonzo     2018-02-19 02:10:08+00:00
# 17559  ImmoralReport   2018-02-19 02:05:04+00:00
# 17560  BrandonSteelFis 2018-02-19 01:57:43+00:00
# 17561  baileybellax    2018-02-19 01:47:37+00:00
# 17562  Suz_BBN         2018-02-19 01:47:15+00:00
# 17563  ONGYEWKHOON5    2018-02-19 01:38:22+00:00
# 17564  roberts_darin   2018-02-19 01:38:11+00:00
# 17565  995PlayFM       2018-02-19 01:25:40+00:00
# 17566  j082298         2018-02-19 01:16:39+00:00
# 17567  Zpirao          2018-02-19 01:11:36+00:00
# 17568  JU2419922       2018-02-19 01:08:58+00:00
# 17569  EddieFeldmann   2018-02-19 01:05:01+00:00
# 17570  trainspeedhump  2018-02-19 01:00:41+00:00
# 17571  aalbqrq         2018-02-19 00:49:59+00:00
# 17572  taralynn1272    2018-02-19 00:32:55+00:00
# 17573  scottolmer      2018-02-19 00:31:20+00:00
# 17574  BlumpCon        2018-02-19 00:12:59+00:00
# 17575  SpockEvil       2018-02-18 23:55:12+00:00
# 17576  hugh_bothwell   2018-02-18 23:53:50+00:00
# 17577  NoahChuck       2018-02-18 23:40:02+00:00
# 17578  ClimateHawk2    2018-02-18 23:25:52+00:00
#
#                                                                                                                                                                                                                                                                                      full_text  \
# 0      population control will not reverse or mitigate climate change here is the logic and evidence populationcontrollaw
# 1      i see climate change deniers are out in force today due to the cold weather in europe they still haven t bothered to research the issue properly and are still hung up on the global warming meaning climatechangeisreal
# 2      convenient truth al gore the father of global warming suggest that we tax ranchers cows passing gas he owns mansion flies around in his personal jet and leaves a carbon footprint like a herd of elephants now the dems switch the name climate change what a hoax
# 3      and yes it s consistent with climate change warming at the poles weakens the jetstream which blows warm air from the west and allows colder air in from the east
# 4      can lee s l do something to safe the global warming and climate changes
# 5      john ashton trying to elain to mayhem and co in necessarily very simple terms that allowing fracking won t help reduce global warming and catastrophic climate breakdown wonder if they ll get the message best keep on with nvda until they do roll on the united resistance
# 6      it might seem counterintuitive but global warming plays a role in blasts of bitter cold weather the reason it influences the jet stream here s how
# 7      convenient truth al gore the father of global warming suggest that we tax ranchers cows passing gas he owns mansion flies around in his personal jet and leaves a carbon footprint like a herd of elephants now the dems switch the name climate change what a hoax
# 8      convenient truth al gore the father of global warming suggest that we tax ranchers cows passing gas he owns mansion flies around in his personal jet and leaves a carbon footprint like a herd of elephants now the dems switch the name climate change what a hoax
# 9      if you want to research the soyboy epidemic causes just allege a link and possible solution to global warming sorry climate change in the research grant application maybe study the combined potential of estrogen and soy flatulence to absorb co and bam the money s in the bank
# 10     wants to address climatechange but not if it means giving up his suvs and helicopter rides exnknew
# 11     climate hypocrite robert de niro so worried about global warming that
# 12     convenient truth al gore the father of global warming suggest that we tax ranchers cows passing gas he owns mansion flies around in his personal jet and leaves a carbon footprint like a herd of elephants now the dems switch the name climate change what a hoax
# 13     wants to address climatechange but not if it means giving up his suvs and helicopter rides exnknew
# 14     wants to address climatechange but not if it means giving up his suvs and helicopter rides exnknew
# 15     soil cannot halt climate change long term field eeriments dating back as far as demonstrate that modern carbon emissions cannot be locked in the ground to halt global warming
# 16     soil cannot halt climate change long term field eeriments dating back as far as demonstrate that modern carbon emissions cannot be locked in the ground to halt global warming
# 17     soil cannot halt climate change long term field eeriments dating back as far as demonstrate that modern carbon emissions cannot be locked in the ground to halt global warming
# 18     big chill from arctic heat
# 19     india plants million trees in hours as part of record breaking environmental campaign
# 20     warming temperatures driven by climate change and strengthening el ni o events are beginning to threaten the tourism economy of costa rica s pacific coast
# 21     india plants million trees in hours as part of record breaking environmental campaign
# 22     india plants million trees in hours as part of record breaking environmental campaign
# 23     could the problem of global warming become so desperate that humans would be willing to take the vast risk of re engineering our environment
# 24     companies around the world have started looking for clarity on how global warming might disrupt their operations in the future
# 25     to meet climate goals california should cut oil production report says
# 26     warming temperatures driven by climate change and strengthening el ni o events are beginning to threaten the tourism economy of costa rica s pacific coast
# 27     india plants million trees in hours as part of record breaking environmental campaign
# 28     when i knewore a out climate change i thought about feedbacks being enhanced by natural variation climate
# 29     india planted million trees in hours
# ...                                     ...
# 17549  politics and global warming october stateofclimate climatechange climateaction climate co via
# 17550  fck climate barbie
# 17551  how big oil takes advantage of climatechange first ship crosses arctic in winter without an icebreaker as global warming causes ice sheets to melt
# 17552  wants to address climatechange but not if it means giving up his suvs and helicopter rides exnknew
# 17553  a new oecd study has found that almost all taxes are too low to help combat global warming we need to do better if we are going to reduce emissions and beatpollution
# 17554  federal government employees do not get family day off so why are you taking it off climate barbie
# 17555  see how global warming will impact you
# 17556  new excuse the warming hole snow covered beaches chilly iguanas they are part of a mysterious hole in global warming via globulwarmingmyth
# 17557  china reassigns soldiers to plant trees in bid to fight pollution meanwhile in america it s all industry industry industry pollution climatechange energy nature
# 17558  china reassigns soldiers to plant trees in bid to fight pollution meanwhile in america it s all industry industry industry pollution climatechange energy nature
# 17559  climatebarbie global warming climatechange hoax liberalismisamentaldisorder
# 17560  hillary clinton now says climate change is sexist misogynistic not only is the american voting public sexist and misogynistic hillary clinton now says but global climate change will also have a disparate impact on women because global warming tren
# 17561  wants to address climatechange but not if it means giving up his suvs and helicopter rides exnknew
# 17562  wants to address climatechange but not if it means giving up his suvs and helicopter rides exnknew
# 17563  a solution to global warming and climate changes a win win situation for all countries
# 17564  opinion the u s government s intelligence agencies warn of big problems ahead because of the warming climate despite what the president might say
# 17565  movingmondays on the midmorninghigh w and china doin good respect
# 17566  china deploys soldiers to plant trees in bid to grow million hectares of new forest this year
# 17567  china deploys soldiers to plant trees in bid to grow million hectares of new forest this year
# 17568  hi doug would u say this very mild end to february is caused by global warming climate change feb was supposed to end on a colder and snowier pattern this warm in february is abnormal and we have never seen this amount of warm before in february in the gtha
# 17569  note to climate denier fb friends if you live in a cold winter climate and it snows and you mockingly say it s global warming you not only don t understand global warming you don t understand how to mock anything
# 17570  although i am in my late s i am proud to be a greeniepunk a greenie because i want the earth to have a future and a genuine punk from the punk generation my new label for the day i m a climate freakout person love you all
# 17571  a group of activists called the valve turners decided to fight global warming by doing whatever it takes
# 17572  education and access to affordable birth control shown to slow global warming y all know grothman doesn t agree with a single thing in that last sentence but i do and will fight to ensure everyone has quality education access to affordable birth control and reduce climate change
# 17573  education and access to affordable birth control shown to slow global warming y all know grothman doesn t agree with a single thing in that last sentence but i do and will fight to ensure everyone has quality education access to affordable birth control and reduce climate change
# 17574  climate change is real climate change is real climate change is real climate change is real i guess she believes if repeats it often enough it will come true notice she never refers to it as man made global warming
# 17575  climate change is real climate change is real climate change is real climate change is real i guess she believes if repeats it often enough it will come true notice she never refers to it as man made global warming
# 17576  dec paper in nature which gives probability of at least c average temperature increase by chance of more than c it s paywalled a quick summary at
# 17577  a leaked draft copy of a new united nations climate change report study says that staying below degrees of warming is likely already out of reach
# 17578  this wasted gas causes the same near term climate pollution as coal fired power plants reports
#
#        truncated  contains_url  favorite_count       location  \
# 0      False      1             0               None
# 1      False      1             0               None
# 2      False      1             0               None
# 3      False      1             0               None
# 4      False      1             0               Singapore
# 5      False      1             0               None
# 6      False      1             0               None
# 7      False      1             0               None
# 8      False      1             0               None
# 9      False      0             0               None
# 10     False      1             0               None
# 11     False      1             0               None
# 12     False      1             3               None
# 13     False      1             0               None
# 14     False      1             0               None
# 15     False      1             0               None
# 16     False      1             0               None
# 17     False      1             2               None
# 18     False      1             0               None
# 19     False      1             0               None
# 20     False      1             0               None
# 21     False      1             0               None
# 22     False      1             0               None
# 23     False      1             0               None
# 24     False      1             3               None
# 25     False      1             0               None
# 26     False      1             0               None
# 27     False      1             0               None
# 28     False      1             0               None
# 29     False      1             0               None
# ...      ...     ..            ..                ...
# 17549  False      1             0               None
# 17550  False      1             0               None
# 17551  False      1             0               None
# 17552  False      1             0               None
# 17553  False      1             0               None
# 17554  False      1             1               None
# 17555  False      1             0               None
# 17556  False      1             0               None
# 17557  False      1             0               None
# 17558  False      1             0               None
# 17559  False      1             0               None
# 17560  False      1             1               None
# 17561  False      1             0               None
# 17562  False      1             0               None
# 17563  False      1             2               Singapore
# 17564  False      1             0               None
# 17565  False      1             6               None
# 17566  False      1             0               None
# 17567  False      1             0               None
# 17568  False      0             0               None
# 17569  False      0             5               None
# 17570  False      1             4               None
# 17571  False      1             0               None
# 17572  False      1             0               None
# 17573  False      1             6               United States
# 17574  False      1             0               None
# 17575  False      1             7               None
# 17576  False      1             1               None
# 17577  False      1             0               None
# 17578  False      1             0               None
#
#                          time_zone  following_count  followers_count  \
# 0      Amsterdam                    94               71
# 1      None                         218              307
# 2      Central Time (US & Canada)   10202            10713
# 3      London                       7031             8057
# 4      None                         3896             806
# 5      None                         222              346
# 6      None                         474              56
# 7      None                         6380             6295
# 8      None                         4991             4951
# 9      None                         313              197
# 10     None                         4412             4307
# 11     Mountain Time (US & Canada)  1131             1146
# 12     None                         4838             3961
# 13     None                         4765             3739
# 14     None                         4904             6000
# 15     Bern                         5969             7610
# 16     None                         2296             2592
# 17     None                         6036             25965
# 18     None                         513              244
# 19     Alaska                       843              1503
# 20     Central Time (US & Canada)   4523             2475
# 21     Central Time (US & Canada)   50               153
# 22     Baghdad                      5617             6449
# 23     Sydney                       688              76
# 24     Central Time (US & Canada)   353812           321631
# 25     Casablanca                   5000             1973
# 26     Eastern Time (US & Canada)   2068             71047
# 27     Athens                       941              2111
# 28     Amsterdam                    603              338
# 29     None                         135              74
# ...     ...                         ...              ..
# 17549  None                         101              18
# 17550  None                         599              434
# 17551  Pacific Time (US & Canada)   77               40
# 17552  None                         270              69
# 17553  New Delhi                    578              433
# 17554  Central Time (US & Canada)   100              32
# 17555  Central Time (US & Canada)   1003             195
# 17556  Eastern Time (US & Canada)   999              774
# 17557  None                         2027             1600
# 17558  None                         139              170
# 17559  None                         3737             17931
# 17560  None                         424              60
# 17561  None                         1311             1412
# 17562  None                         2592             1376
# 17563  None                         3896             805
# 17564  None                         139              35
# 17565  Midway Island                1435             34505
# 17566  Eastern Time (US & Canada)   3245             2872
# 17567  Mexico City                  135              70
# 17568  None                         1698             138
# 17569  None                         872              405
# 17570  None                         204              155
# 17571  None                         54               8
# 17572  None                         1550             1206
# 17573  Central Time (US & Canada)   1025             725
# 17574  None                         1698             637
# 17575  None                         1543             1477
# 17576  Eastern Time (US & Canada)   516              76
# 17577  None                         2878             1633
# 17578  Pacific Time (US & Canada)   785              486
#
#        retweet_count  Polarity  Subjectivity
# 0      0              0.000000  0.000000
# 1      0             -0.181250  0.368750
# 2      3              0.000000  0.150000
# 3      2              0.425000  0.425000
# 4      0              0.250000  0.250000
# 5      4              0.333333  0.254762
# 6      153           -0.233333  0.500000
# 7      3              0.000000  0.150000
# 8      3              0.000000  0.150000
# 9      0             -0.125000  0.750000
# 10     1966           0.200000  0.100000
# 11     21             0.000000  0.000000
# 12     3              0.000000  0.150000
# 13     1966           0.200000  0.100000
# 14     1966           0.200000  0.100000
# 15     0              0.050000  0.340000
# 16     0              0.050000  0.340000
# 17     2              0.050000  0.340000
# 18     0              0.000000  0.100000
# 19     554            0.000000  0.000000
# 20     1              0.000000  0.000000
# 21     554            0.000000  0.000000
# 22     554            0.000000  0.000000
# 23     0             -0.087500  0.687500
# 24     0              0.000000  0.062500
# 25     2              0.000000  0.000000
# 26     1              0.000000  0.000000
# 27     554            0.000000  0.000000
# 28     0              0.100000  0.400000
# 29     3              0.000000  0.000000
# ...   ..                   ...       ...
# 17549  0              0.000000  0.000000
# 17550  3              0.000000  0.000000
# 17551  40             0.083333  0.144444
# 17552  1969           0.200000  0.100000
# 17553  40             0.159091  0.313636
# 17554  0              0.000000  0.000000
# 17555  39             0.000000  0.000000
# 17556  0             -0.102727  0.480909
# 17557  17             0.000000  0.000000
# 17558  17             0.000000  0.000000
# 17559  1              0.000000  0.000000
# 17560  0              0.000000  0.213333
# 17561  1969           0.200000  0.100000
# 17562  1969           0.200000  0.100000
# 17563  1              0.533333  0.266667
# 17564  250            0.000000  0.100000
# 17565  0              0.700000  0.600000
# 17566  0              0.136364  0.454545
# 17567  0              0.136364  0.454545
# 17568  0              0.408333  0.462500
# 17569  0             -0.092727  0.500000
# 17570  5              0.256061  0.546591
# 17571  80             0.000000  0.000000
# 17572  1             -0.092857  0.170238
# 17573  1             -0.092857  0.170238
# 17574  3              0.164286  0.335714
# 17575  3              0.164286  0.335714
# 17576  0              0.095833  0.450000
# 17577  255            0.068182  0.727273
# 17578  42            -0.033333  0.175000
#
# [17579 rows x 13 columns]

# %% [markdown]
# ## Location

# %%
pd.unique(tweetsDF.location)
# Out:
# array([None, 'Singapore', 'Australia', 'United Kingdom', 'India',
#        'Canada', 'United States', 'Kenya', 'Indonesia', 'Malaysia',
#        'Mexico', 'Spain', 'Thailand', 'Austria', 'Ireland', 'Denmark',
#        'Greece', 'Mali', 'Norway', 'Japan', 'Finland', 'New Zealand',
#        'Fiji'], dtype=object)

# %%
pd.unique(tweetsDF.time_zone)
# Out:
# array(['Amsterdam', None, 'Central Time (US & Canada)', 'London',
#        'Mountain Time (US & Canada)', 'Bern', 'Alaska', 'Baghdad',
#        'Sydney', 'Casablanca', 'Eastern Time (US & Canada)', 'Athens',
#        'Pacific Time (US & Canada)', 'America/Chicago', 'Nairobi',
#        'Quito', 'Bogota', 'Europe/London', 'Brasilia', 'Arizona',
#        'Midway Island', 'Kabul', 'Brisbane', 'Helsinki', 'Wellington',
#        'Edinburgh', 'Atlantic Time (Canada)', 'Dublin', 'Pretoria',
#        'Paris', 'Copenhagen', 'Melbourne', 'Stockholm', 'Africa/Nairobi',
#        'Berlin', 'Belgrade', 'Canberra', 'Bucharest', "Nuku'alofa",
#        'America/Los_Angeles', 'Monterrey', 'Madrid', 'Hawaii', 'Warsaw',
#        'Brussels', 'Bangkok', 'Hanoi', 'Greenland', 'Vienna',
#        'Europe/Madrid', 'Kuala Lumpur', 'Karachi', 'Kyiv', 'Buenos Aires',
#        'Tbilisi', 'New Delhi', 'Mid-Atlantic', 'Prague',
#        'America/Toronto', 'PST', 'Singapore', 'Perth', 'Budapest',
#        'Santiago', 'America/New_York', 'Chennai', 'Cairo', 'Islamabad',
#        'Zagreb', 'America/Phoenix', 'Abu Dhabi', 'Tokyo', 'Europe/Berlin',
#        'Ljubljana', 'Adelaide', 'La Paz', 'Irkutsk', 'Mexico City',
#        'Caracas', 'Dhaka', 'Riyadh', 'Hobart',
#        'International Date Line West', 'Tehran', 'Jakarta', 'Mumbai',
#        'Hong Kong', 'West Central Africa', 'Beijing', 'Newfoundland',
#        'Europe/Athens', 'Asia/Kolkata', 'Rome', 'New Caledonia',
#        'America/Santiago', 'Kathmandu', 'Auckland', 'America/Detroit',
#        'Australia/Brisbane', 'America/Denver', 'Indiana (East)', 'Darwin',
#        'UTC', 'Solomon Is.', 'Jerusalem', 'Africa/Dar_es_Salaam',
#        'Saskatchewan', 'GMT', 'Seoul', 'Georgetown', 'Minsk', 'Lima',
#        'Lisbon', 'Europe/Zurich', 'America/Halifax', 'America/Edmonton',
#        'Asia/Calcutta', 'Africa/Algiers', 'Europe/Moscow', 'Riga',
#        'Tijuana', 'Europe/Bucharest', 'Europe/Amsterdam', 'Bratislava',
#        'Europe/Istanbul', 'Urumqi', 'Africa/Kampala', 'Istanbul',
#        'Europe/Dublin', 'Kolkata', 'Kuwait', 'Baku', 'Rangoon', 'Yakutsk',
#        'Pacific/Auckland', 'Ekaterinburg', 'Chihuahua', 'America/Boise',
#        'Guam', 'America/Vancouver', 'Central America', 'Europe/Rome',
#        'Tallinn', 'BST', 'Volgograd', 'Almaty', 'Europe/Brussels',
#        'Asia/Bangkok', 'Australia/Sydney', 'Monrovia', 'Moscow',
#        'Mazatlan', 'Africa/Lagos', 'Africa/Johannesburg', 'Muscat',
#        'Asia/Baghdad', 'St. Petersburg', 'Europe/Helsinki',
#        'Sri Jayawardenepura', 'Pacific/Honolulu', 'EST', 'MDT', 'Osaka',
#        'Pacific/Fiji', 'Sofia', 'Asia/Karachi', 'Astana',
#        'Australia/Hobart', 'Harare', 'CAT', 'Europe/Kiev', 'Europe/Paris',
#        'America/Tegucigalpa', 'America/Argentina/Buenos_Aires', 'Vilnius',
#        'GMT+8', 'America/Tijuana', 'America/Dawson', 'Asia/Dubai',
#        'Asia/Manila', 'Taipei', 'EDT', 'CST', 'Asia/Kuala_Lumpur', 'Fiji',
#        'America/Puerto_Rico', 'Azores', 'Asia/Jakarta',
#        'America/Montreal'], dtype=object)

# %%
sum(tweetsDF.location.value_counts())
# Out:
# 229

# %%
sum(tweetsDF.time_zone.value_counts())
# Out:
# 10438

# %%
with open('clean_tweets.pkl', 'wb') as picklefile: # wb: write, binary
    pickle.dump(tweetsDF, picklefile) #dump data into pickle file
