# %% [markdown]
# # Project 3: Predicting new Airbnb users' first destinations
# # Part 2: Data Cleaning and Exporting to PostgreSQL

# %%
import pandas as pd
import matplotlib.pyplot as plt
from patsy import dmatrix
import datetime
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
age_gender_bkts = pd.read_csv('./airbnb firstdestinations/age_gender_bkts.csv')

# %%
countries = pd.read_csv('./airbnb firstdestinations/countries.csv')

# %%
sessions = pd.read_csv('./airbnb firstdestinations/sessions.csv')

# %%
users = pd.read_csv('./airbnb firstdestinations/train_users.csv')

# %%
age_gender_bkts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 5 columns):
# age_bucket                 420 non-null object
# country_destination        420 non-null object
# gender                     420 non-null object
# population_in_thousands    420 non-null float64
# year                       420 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 16.5+ KB

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
# country_destination              10 non-null object
# lat_destination                  10 non-null float64
# lng_destination                  10 non-null float64
# distance_km                      10 non-null float64
# destination_km2                  10 non-null float64
# destination_language             10 non-null object
# language_levenshtein_distance    10 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 640.0+ bytes

# %%
sessions.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# user_id          10533241 non-null object
# action           10488111 non-null object
# action_type      9441533 non-null object
# action_detail    9441533 non-null object
# device_type      10567737 non-null object
# secs_elapsed     10431706 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %% [markdown]
# - missing user_id s (delete?)
# - missing actions
# - missing acction_types & action_detail
# - missing secs_elapsed (delete?)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %% [markdown]
# - Missing age data
# - missing gender data
# - missing date_first_active data (going to delete this because if we're predicting the first booking, we won't know the date)
# - missing first_affiliate_tracked

# %%
#users = users.drop('date_first_booking', axis = 1)

# %%
countries
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
# 5                  GB        54.633220        -3.432277    6883.6590
# 6                  IT        41.873990        12.564167    8636.6310
# 7                  NL        52.133057         5.295250    7524.3203
# 8                  PT        39.553444        -7.839319    7355.2534
# 9                  US        36.966427       -95.844030       0.0000
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61
# 3         505370.0                   spa                          92.25
# 4         643801.0                   fra                          92.06
# 5         243610.0                   eng                           0.00
# 6         301340.0                   ita                          89.40
# 7          41543.0                   nld                          63.22
# 8          92090.0                   por                          95.45
# 9        9826675.0                   eng                           0.00

# %%
sessions
# Out:
#              user_id                 action       action_type  \
# 0         d1mm9tcy42                 lookup               NaN
# 1         d1mm9tcy42         search_results             click
# 2         d1mm9tcy42                 lookup               NaN
# 3         d1mm9tcy42         search_results             click
# 4         d1mm9tcy42                 lookup               NaN
# 5         d1mm9tcy42         search_results             click
# 6         d1mm9tcy42                 lookup               NaN
# 7         d1mm9tcy42            personalize              data
# 8         d1mm9tcy42                  index              view
# 9         d1mm9tcy42                 lookup               NaN
# 10        d1mm9tcy42         search_results             click
# 11        d1mm9tcy42                 lookup               NaN
# 12        d1mm9tcy42            personalize              data
# 13        d1mm9tcy42                  index              view
# 14        d1mm9tcy42       similar_listings              data
# 15        d1mm9tcy42  ajax_refresh_subtotal             click
# 16        d1mm9tcy42       similar_listings              data
# 17        d1mm9tcy42  ajax_refresh_subtotal             click
# 18        d1mm9tcy42                   show               NaN
# 19        d1mm9tcy42            personalize              data
# 20        d1mm9tcy42                   show              view
# 21        d1mm9tcy42                 lookup               NaN
# 22        d1mm9tcy42         search_results             click
# 23        d1mm9tcy42                 lookup               NaN
# 24        d1mm9tcy42         search_results             click
# 25        d1mm9tcy42            personalize              data
# 26        d1mm9tcy42                 lookup               NaN
# 27        d1mm9tcy42                  index              view
# 28        d1mm9tcy42                   show               NaN
# 29        d1mm9tcy42            personalize              data
# ...              ...                    ...               ...
# 10567707  87k0fy4ugm                 update            submit
# 10567708  87k0fy4ugm                 create         -unknown-
# 10567709  87k0fy4ugm            personalize              data
# 10567710  87k0fy4ugm         header_userpic              data
# 10567711  87k0fy4ugm                 create            submit
# 10567712  87k0fy4ugm                   show              view
# 10567713  87k0fy4ugm         header_userpic              data
# 10567714  87k0fy4ugm            personalize              data
# 10567715  87k0fy4ugm  ajax_refresh_subtotal             click
# 10567716  87k0fy4ugm       similar_listings              data
# 10567717  87k0fy4ugm                  index              view
# 10567718  87k0fy4ugm          confirm_email             click
# 10567719  87k0fy4ugm           authenticate            submit
# 10567720  87k0fy4ugm              dashboard              view
# 10567721  9uqfg8txu3                   show              view
# 10567722  9uqfg8txu3                 update            submit
# 10567723  9uqfg8txu3                   edit              view
# 10567724  9uqfg8txu3  languages_multiselect         -unknown-
# 10567725  9uqfg8txu3                 create            submit
# 10567726  9uqfg8txu3               callback  partner_callback
# 10567727  9uqfg8txu3                 active         -unknown-
# 10567728  9uqfg8txu3                 create            submit
# 10567729  9uqfg8txu3         header_userpic              data
# 10567730  9uqfg8txu3                   edit              view
# 10567731  9uqfg8txu3                   edit              view
# 10567732  9uqfg8txu3              dashboard              view
# 10567733  9uqfg8txu3                   edit              view
# 10567734  9uqfg8txu3          webcam_upload         -unknown-
# 10567735  9uqfg8txu3                 active         -unknown-
# 10567736  9uqfg8txu3       show_personalize              data
#
#                         action_detail      device_type  secs_elapsed
# 0                                 NaN  Windows Desktop         319.0
# 1                 view_search_results  Windows Desktop       67753.0
# 2                                 NaN  Windows Desktop         301.0
# 3                 view_search_results  Windows Desktop       22141.0
# 4                                 NaN  Windows Desktop         435.0
# 5                 view_search_results  Windows Desktop        7703.0
# 6                                 NaN  Windows Desktop         115.0
# 7             wishlist_content_update  Windows Desktop         831.0
# 8                 view_search_results  Windows Desktop       20842.0
# 9                                 NaN  Windows Desktop         683.0
# 10                view_search_results  Windows Desktop       59274.0
# 11                                NaN  Windows Desktop          95.0
# 12            wishlist_content_update  Windows Desktop        1399.0
# 13                view_search_results  Windows Desktop       74886.0
# 14                   similar_listings  Windows Desktop         255.0
# 15        change_trip_characteristics  Windows Desktop        8134.0
# 16                   similar_listings  Windows Desktop         183.0
# 17        change_trip_characteristics  Windows Desktop      175570.0
# 18                                NaN  Windows Desktop          86.0
# 19            wishlist_content_update  Windows Desktop        1535.0
# 20                                 p3  Windows Desktop       83251.0
# 21                                NaN  Windows Desktop         360.0
# 22                view_search_results  Windows Desktop        2488.0
# 23                                NaN  Windows Desktop         456.0
# 24                view_search_results  Windows Desktop       10053.0
# 25            wishlist_content_update  Windows Desktop          50.0
# 26                                NaN  Windows Desktop        1996.0
# 27                view_search_results  Windows Desktop       82263.0
# 28                                NaN  Windows Desktop         102.0
# 29            wishlist_content_update  Windows Desktop         673.0
# ...                               ...              ...           ...
# 10567707               update_listing      Mac Desktop        3490.0
# 10567708                    -unknown-      Mac Desktop       26491.0
# 10567709      wishlist_content_update      Mac Desktop         189.0
# 10567710               header_userpic      Mac Desktop         698.0
# 10567711                  create_user      Mac Desktop           NaN
# 10567712                           p3      Mac Desktop       21062.0
# 10567713               header_userpic           iPhone         897.0
# 10567714      wishlist_content_update      Mac Desktop          17.0
# 10567715  change_trip_characteristics      Mac Desktop         602.0
# 10567716             similar_listings      Mac Desktop         257.0
# 10567717          view_search_results      Mac Desktop       14711.0
# 10567718           confirm_email_link           iPhone      253296.0
# 10567719                        login           iPhone       26581.0
# 10567720                    dashboard           iPhone        2694.0
# 10567721                 user_profile  Windows Desktop         447.0
# 10567722          update_user_profile  Windows Desktop      124020.0
# 10567723                 edit_profile  Windows Desktop       22920.0
# 10567724                    -unknown-  Windows Desktop      575816.0
# 10567725         create_phone_numbers  Windows Desktop       57382.0
# 10567726               oauth_response  Windows Desktop           NaN
# 10567727                    -unknown-        -unknown-         353.0
# 10567728         create_phone_numbers  Windows Desktop       27206.0
# 10567729               header_userpic  Windows Desktop        1939.0
# 10567730                 edit_profile  Windows Desktop     1752436.0
# 10567731                 edit_profile  Windows Desktop       15875.0
# 10567732                    dashboard  Windows Desktop         556.0
# 10567733                 edit_profile  Windows Desktop        6624.0
# 10567734                    -unknown-  Windows Desktop      200125.0
# 10567735                    -unknown-        -unknown-       17624.0
# 10567736  user_profile_content_update  Windows Desktop        1221.0
#
# [10567737 rows x 6 columns]

# %% [markdown]
# Possible features:
# - total secs_elapsed per user
# - total secs_elapsed per user per device
# - number of sessions per user
# - (number of actions per user)

# %%
users.head(20)
# Out:
#             id date_account_created  timestamp_first_active  \
# 0   gxn3p5htnn           2010-06-28          20090319043255
# 1   820tgsjxq7           2011-05-25          20090523174809
# 2   4ft3gnwmtx           2010-09-28          20090609231247
# 3   bjjt8pjhuk           2011-12-05          20091031060129
# 4   87mebub9p4           2010-09-14          20091208061105
# 5   osr2jwljor           2010-01-01          20100101215619
# 6   lsw9q7uk0j           2010-01-02          20100102012558
# 7   0d01nltbrs           2010-01-03          20100103191905
# 8   a1vcnhxeij           2010-01-04          20100104004211
# 9   6uh8zyj2gn           2010-01-04          20100104023758
# 10  yuuqmid2rp           2010-01-04          20100104194251
# 11  om1ss59ys8           2010-01-05          20100105051812
# 12  k6np330cm1           2010-01-05          20100105060859
# 13  dy3rgx56cu           2010-01-05          20100105083259
# 14  ju3h98ch3w           2010-01-07          20100107055820
# 15  v4d5rl22px           2010-01-07          20100107204555
# 16  2dwbwkx056           2010-01-07          20100107215125
# 17  frhre329au           2010-01-07          20100107224625
# 18  cxlg85pg1r           2010-01-08          20100108015641
# 19  gdka1q5ktd           2010-01-10          20100110010817
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN  -unknown-   NaN      facebook            0       en
# 1                 NaN       MALE  38.0      facebook            0       en
# 2          2010-08-02     FEMALE  56.0         basic            3       en
# 3          2012-09-08     FEMALE  42.0      facebook            0       en
# 4          2010-02-18  -unknown-  41.0         basic            0       en
# 5          2010-01-02  -unknown-   NaN         basic            0       en
# 6          2010-01-05     FEMALE  46.0         basic            0       en
# 7          2010-01-13     FEMALE  47.0         basic            0       en
# 8          2010-07-29     FEMALE  50.0         basic            0       en
# 9          2010-01-04  -unknown-  46.0         basic            0       en
# 10         2010-01-06     FEMALE  36.0         basic            0       en
# 11                NaN     FEMALE  47.0         basic            0       en
# 12         2010-01-18  -unknown-   NaN         basic            0       en
# 13                NaN     FEMALE  37.0         basic            0       en
# 14                NaN     FEMALE  36.0         basic            0       en
# 15         2010-01-08     FEMALE  33.0         basic            0       en
# 16                NaN  -unknown-   NaN         basic            0       en
# 17         2010-01-09  -unknown-  31.0         basic            0       en
# 18                NaN  -unknown-   NaN         basic            0       en
# 19         2010-01-10     FEMALE  29.0         basic            0       en
#
#    affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0             direct             direct               untracked        Web
# 1                seo             google               untracked        Web
# 2             direct             direct               untracked        Web
# 3             direct             direct               untracked        Web
# 4             direct             direct               untracked        Web
# 5              other              other                     omg        Web
# 6              other         craigslist               untracked        Web
# 7             direct             direct                     omg        Web
# 8              other         craigslist               untracked        Web
# 9              other         craigslist                     omg        Web
# 10             other         craigslist               untracked        Web
# 11             other         craigslist               untracked        Web
# 12            direct             direct                     NaN        Web
# 13             other         craigslist                  linked        Web
# 14             other         craigslist               untracked        Web
# 15            direct             direct               untracked        Web
# 16             other         craigslist                     NaN        Web
# 17             other         craigslist                     NaN        Web
# 18               seo           facebook                     NaN        Web
# 19            direct             direct               untracked        Web
#
#    first_device_type  first_browser country_destination
# 0        Mac Desktop         Chrome                 NDF
# 1        Mac Desktop         Chrome                 NDF
# 2    Windows Desktop             IE                  US
# 3        Mac Desktop        Firefox               other
# 4        Mac Desktop         Chrome                  US
# 5        Mac Desktop         Chrome                  US
# 6        Mac Desktop         Safari                  US
# 7        Mac Desktop         Safari                  US
# 8        Mac Desktop         Safari                  US
# 9        Mac Desktop        Firefox                  US
# 10       Mac Desktop        Firefox                  US
# 11            iPhone      -unknown-                 NDF
# 12     Other/Unknown      -unknown-                  FR
# 13       Mac Desktop        Firefox                 NDF
# 14            iPhone  Mobile Safari                 NDF
# 15   Windows Desktop         Chrome                  CA
# 16     Other/Unknown      -unknown-                 NDF
# 17     Other/Unknown      -unknown-                  US
# 18     Other/Unknown      -unknown-                 NDF
# 19       Mac Desktop         Chrome                  FR

# %% [markdown]
# ### Cleaning dates, gender, browser and affiliates

# %% [markdown]
# Clean:
# - dates to datetimes
# - unknowns to NaNs in gender, first_browser and untracked to NaNs in first_affiliate_tracked

# %%
users['date_account_created'] = pd.to_datetime(users['date_account_created'], infer_datetime_format = True)
users['timestamp_first_active'] = pd.to_datetime(users['timestamp_first_active'], format = '%Y%m%d%H%M%S')

# %%
#users.gender = users.gender.replace('-unknown-', np.nan)
#users.first_browser = users.first_browser.replace('-unknown-', np.nan)
#users.first_affiliate_tracked = users.first_affiliate_tracked.replace('untracked',np.nan)

# %%
for col in users:
    print(col)
    print(users[col].describe())
    print('-----------------')
# Out:
# id
# count         213451
# unique        213451
# top       f5u190liup
# freq               1
# Name: id, dtype: object
# -----------------
# date_account_created
# count                  213451
# unique                   1634
# top       2014-05-13 00:00:00
# freq                      674
# first     2010-01-01 00:00:00
# last      2014-06-30 00:00:00
# Name: date_account_created, dtype: object
# -----------------
# timestamp_first_active
# count                  213451
# unique                 213451
# top       2013-07-01 05:26:34
# freq                        1
# first     2009-03-19 04:32:55
# last      2014-06-30 23:58:24
# Name: timestamp_first_active, dtype: object
# -----------------
# date_first_booking
# count          88908
# unique          1976
# top       2014-05-22
# freq             248
# Name: date_first_booking, dtype: object
# -----------------
# gender
# count        213451
# unique            4
# top       -unknown-
# freq          95688
# Name: gender, dtype: object
# -----------------
# age
# count    125461.000000
# mean         49.668335
# std         155.666612
# min           1.000000
# 25%          28.000000
# 50%          34.000000
# 75%          43.000000
# max        2014.000000
# Name: age, dtype: float64
# -----------------
# signup_method
# count     213451
# unique         3
# top        basic
# freq      152897
# Name: signup_method, dtype: object
# -----------------
# signup_flow
# count    213451.000000
# mean          3.267387
# std           7.637707
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          25.000000
# Name: signup_flow, dtype: float64
# -----------------
# language
# count     213451
# unique        25
# top           en
# freq      206314
# Name: language, dtype: object
# -----------------
# affiliate_channel
# count     213451
# unique         8
# top       direct
# freq      137727
# Name: affiliate_channel, dtype: object
# -----------------
# affiliate_provider
# count     213451
# unique        18
# top       direct
# freq      137426
# Name: affiliate_provider, dtype: object
# -----------------
# first_affiliate_tracked
# count        207386
# unique            7
# top       untracked
# freq         109232
# Name: first_affiliate_tracked, dtype: object
# -----------------
# signup_app
# count     213451
# unique         4
# top          Web
# freq      182717
# Name: signup_app, dtype: object
# -----------------
# first_device_type
# count          213451
# unique              9
# top       Mac Desktop
# freq            89600
# Name: first_device_type, dtype: object
# -----------------
# first_browser
# count     213451
# unique        52
# top       Chrome
# freq       63845
# Name: first_browser, dtype: object
# -----------------
# country_destination
# count     213451
# unique        12
# top          NDF
# freq      124543
# Name: country_destination, dtype: object
# -----------------

# %%
users.gender.value_counts()
# Out:
# -unknown-    95688
# FEMALE       63041
# MALE         54440
# OTHER          282
# Name: gender, dtype: int64

# %% [markdown]
# ### Cleaning age data

# %% [markdown]
# Airbnb age regulations:
#
# 'You must be 18 or older to create an account. In order to use the Airbnb site and services, you must be 18 years or older. It's against our Terms of Service to create an account to travel or host unless you're at least 18 years old.'

# %%
sorted(users.age.unique())
# Out:
# [nan,
#  1.0,
#  2.0,
#  4.0,
#  5.0,
#  15.0,
#  16.0,
#  17.0,
#  18.0,
#  19.0,
#  20.0,
#  21.0,
#  22.0,
#  23.0,
#  24.0,
#  25.0,
#  26.0,
#  27.0,
#  28.0,
#  29.0,
#  30.0,
#  31.0,
#  32.0,
#  33.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  38.0,
#  39.0,
#  40.0,
#  41.0,
#  42.0,
#  43.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  48.0,
#  49.0,
#  50.0,
#  51.0,
#  52.0,
#  53.0,
#  54.0,
#  55.0,
#  56.0,
#  57.0,
#  58.0,
#  59.0,
#  60.0,
#  61.0,
#  62.0,
#  63.0,
#  64.0,
#  65.0,
#  66.0,
#  67.0,
#  68.0,
#  69.0,
#  70.0,
#  71.0,
#  72.0,
#  73.0,
#  74.0,
#  75.0,
#  76.0,
#  77.0,
#  78.0,
#  79.0,
#  80.0,
#  81.0,
#  82.0,
#  83.0,
#  84.0,
#  85.0,
#  86.0,
#  87.0,
#  88.0,
#  89.0,
#  90.0,
#  91.0,
#  92.0,
#  93.0,
#  94.0,
#  95.0,
#  96.0,
#  97.0,
#  98.0,
#  99.0,
#  100.0,
#  101.0,
#  102.0,
#  103.0,
#  104.0,
#  105.0,
#  106.0,
#  107.0,
#  108.0,
#  109.0,
#  110.0,
#  111.0,
#  112.0,
#  113.0,
#  115.0,
#  132.0,
#  150.0,
#  1924.0,
#  1925.0,
#  1926.0,
#  1927.0,
#  1928.0,
#  1929.0,
#  1931.0,
#  1932.0,
#  1933.0,
#  1935.0,
#  1936.0,
#  1938.0,
#  1942.0,
#  1947.0,
#  1949.0,
#  1952.0,
#  1953.0,
#  1995.0,
#  2008.0,
#  2013.0,
#  2014.0]

# %% [markdown]
# - If age is less than 18, replace with NaN.
# - If age is greater than 150, it's in year of birth format, so take value from 2014 (this data is from 2014).
# - If age is less than 150, but greater than 122 (longest known human lifespan), replace with NaN.

# %%
users.loc[users.age < 18,'age'] = np.nan
users.loc[users.age > 150, 'age'] = 2014 - users.age
users.loc[users.age > 122, 'age'] = np.nan

# %%
users
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28    2009-03-19 04:32:55
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# 5       osr2jwljor           2010-01-01    2010-01-01 21:56:19
# 6       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 7       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# 8       a1vcnhxeij           2010-01-04    2010-01-04 00:42:11
# 9       6uh8zyj2gn           2010-01-04    2010-01-04 02:37:58
# 10      yuuqmid2rp           2010-01-04    2010-01-04 19:42:51
# 11      om1ss59ys8           2010-01-05    2010-01-05 05:18:12
# 12      k6np330cm1           2010-01-05    2010-01-05 06:08:59
# 13      dy3rgx56cu           2010-01-05    2010-01-05 08:32:59
# 14      ju3h98ch3w           2010-01-07    2010-01-07 05:58:20
# 15      v4d5rl22px           2010-01-07    2010-01-07 20:45:55
# 16      2dwbwkx056           2010-01-07    2010-01-07 21:51:25
# 17      frhre329au           2010-01-07    2010-01-07 22:46:25
# 18      cxlg85pg1r           2010-01-08    2010-01-08 01:56:41
# 19      gdka1q5ktd           2010-01-10    2010-01-10 01:08:17
# 20      qdubonn3uk           2010-01-10    2010-01-10 15:21:20
# 21      qsibmuz9sx           2010-01-10    2010-01-10 22:09:41
# 22      80f7dwscrn           2010-01-11    2010-01-11 03:14:38
# 23      jha93x042q           2010-01-11    2010-01-11 22:40:15
# 24      7i49vnuav6           2010-01-11    2010-01-11 23:08:08
# 25      al8bcetz0g           2010-01-12    2010-01-12 13:14:44
# 26      bjg0m5otl3           2010-01-12    2010-01-12 15:54:20
# 27      hfrl5gle36           2010-01-12    2010-01-12 20:59:49
# 28      tp6x3md0n4           2010-01-13    2010-01-13 04:46:50
# 29      hql77nu2lk           2010-01-13    2010-01-13 06:43:33
# ...            ...                  ...                    ...
# 213421  c98s3h7kgj           2014-06-30    2014-06-30 23:11:37
# 213422  ytmpiwb8hj           2014-06-30    2014-06-30 23:12:46
# 213423  3dx1jk6yk2           2014-06-30    2014-06-30 23:15:48
# 213424  hcfj07iowv           2014-06-30    2014-06-30 23:18:59
# 213425  l1f71f9vsj           2014-06-30    2014-06-30 23:21:19
# 213426  15bj4ahmhf           2014-06-30    2014-06-30 23:23:31
# 213427  qwpybxfjdl           2014-06-30    2014-06-30 23:25:39
# 213428  k4t61wuvyq           2014-06-30    2014-06-30 23:26:34
# 213429  mhh7b52z44           2014-06-30    2014-06-30 23:27:12
# 213430  79wk7k2k5t           2014-06-30    2014-06-30 23:31:32
# 213431  ftwmocvwlq           2014-06-30    2014-06-30 23:32:03
# 213432  rg7ayg1tob           2014-06-30    2014-06-30 23:32:24
# 213433  2f24umzkuv           2014-06-30    2014-06-30 23:34:27
# 213434  or77n2ojuj           2014-06-30    2014-06-30 23:36:40
# 213435  0a5bnb9bs4           2014-06-30    2014-06-30 23:38:51
# 213436  6fzrn49sfn           2014-06-30    2014-06-30 23:41:13
# 213437  r0jq0devgy           2014-06-30    2014-06-30 23:42:43
# 213438  v5lq9bj8gv           2014-06-30    2014-06-30 23:44:29
# 213439  msucfwmlzc           2014-06-30    2014-06-30 23:47:29
# 213440  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 213441  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 213442  rf0ay567js           2014-06-30    2014-06-30 23:53:09
# 213443  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 213444  40o1ivh6cb           2014-06-30    2014-06-30 23:53:52
# 213445  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# 1                     NaN       MALE  38.0      facebook            0
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 11                    NaN     FEMALE  47.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 13                    NaN     FEMALE  37.0         basic            0
# 14                    NaN     FEMALE  36.0         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 16                    NaN  -unknown-   NaN         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 18                    NaN  -unknown-   NaN         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 23                    NaN  -unknown-   NaN         basic            0
# 24                    NaN     FEMALE  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 26                    NaN  -unknown-   NaN         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213421                NaN  -unknown-   NaN         basic            0
# 213422                NaN  -unknown-   NaN         basic            0
# 213423                NaN     FEMALE  20.0      facebook           25
# 213424                NaN     FEMALE  32.0      facebook            0
# 213425                NaN     FEMALE  30.0      facebook            0
# 213426                NaN  -unknown-   NaN         basic            0
# 213427                NaN  -unknown-   NaN         basic            0
# 213428                NaN  -unknown-   NaN         basic           23
# 213429                NaN  -unknown-   NaN         basic           25
# 213430                NaN  -unknown-  19.0         basic            0
# 213431                NaN  -unknown-   NaN         basic            0
# 213432                NaN       MALE  31.0      facebook            0
# 213433                NaN  -unknown-   NaN         basic            0
# 213434                NaN  -unknown-   NaN         basic            0
# 213435                NaN  -unknown-   NaN         basic            0
# 213436                NaN  -unknown-   NaN         basic           25
# 213437                NaN  -unknown-   NaN         basic           23
# 213438                NaN  -unknown-   NaN         basic           25
# 213439         2015-03-16       MALE  43.0         basic            0
# 213440                NaN     FEMALE  24.0         basic           25
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213442                NaN  -unknown-   NaN         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213444                NaN  -unknown-   NaN         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
# 213446                NaN       MALE  32.0         basic            0
# 213447                NaN  -unknown-   NaN         basic            0
# 213448                NaN  -unknown-  32.0         basic            0
# 213449                NaN  -unknown-   NaN         basic           25
# 213450                NaN  -unknown-   NaN         basic           25
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 0            en            direct             direct               untracked
# 1            en               seo             google               untracked
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# 7            en            direct             direct                     omg
# 8            en             other         craigslist               untracked
# 9            en             other         craigslist                     omg
# 10           en             other         craigslist               untracked
# 11           en             other         craigslist               untracked
# 12           en            direct             direct                     NaN
# 13           en             other         craigslist                  linked
# 14           en             other         craigslist               untracked
# 15           en            direct             direct               untracked
# 16           en             other         craigslist                     NaN
# 17           en             other         craigslist                     NaN
# 18           en               seo           facebook                     NaN
# 19           en            direct             direct               untracked
# 20           en            direct             direct                     NaN
# 21           en            direct             direct                  linked
# 22           en               seo             google               untracked
# 23           en             other         craigslist               untracked
# 24           en               seo             google               untracked
# 25           en             other         craigslist               untracked
# 26           en             other              other               untracked
# 27           en             other         craigslist               untracked
# 28           en            direct             direct                     NaN
# 29           en            direct             direct               untracked
# ...         ...               ...                ...                     ...
# 213421       en            direct             direct                  linked
# 213422       en            direct             direct               untracked
# 213423       en            direct             direct               untracked
# 213424       en            direct             direct                  linked
# 213425       en            direct             direct                  linked
# 213426       en            direct             direct               untracked
# 213427       en            direct             direct                  linked
# 213428       en            direct             direct               untracked
# 213429       en            direct             direct               untracked
# 213430       en            direct             direct                  linked
# 213431       en            direct             direct               untracked
# 213432       en            direct             direct           tracked-other
# 213433       en         sem-brand             google               untracked
# 213434       en               seo           facebook                 product
# 213435       en               seo             google               untracked
# 213436       en            direct             direct               untracked
# 213437       en            direct             direct               untracked
# 213438       en            direct             direct               untracked
# 213439       en            direct             direct               untracked
# 213440       en            direct             direct               untracked
# 213441       en            direct             direct                  linked
# 213442       en         sem-brand             google                     omg
# 213443       en         sem-brand             google                  linked
# 213444       en            direct             direct                  linked
# 213445       en         sem-brand             google                     omg
# 213446       en         sem-brand             google                     omg
# 213447       en            direct             direct                  linked
# 213448       en            direct             direct               untracked
# 213449       en             other              other           tracked-other
# 213450       en            direct             direct               untracked
#
#        signup_app first_device_type  first_browser country_destination
# 0             Web       Mac Desktop         Chrome                 NDF
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 12            Web     Other/Unknown      -unknown-                  FR
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 16            Web     Other/Unknown      -unknown-                 NDF
# 17            Web     Other/Unknown      -unknown-                  US
# 18            Web     Other/Unknown      -unknown-                 NDF
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 23            Web       Mac Desktop         Safari                 NDF
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 26            Web     Other/Unknown      -unknown-                 NDF
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# ...           ...               ...            ...                 ...
# 213421        Web       Mac Desktop        Firefox                 NDF
# 213422        Web   Windows Desktop             IE                 NDF
# 213423        iOS            iPhone      -unknown-                 NDF
# 213424        Web   Windows Desktop         Chrome                 NDF
# 213425        Web   Windows Desktop         Chrome                 NDF
# 213426      Moweb     Android Phone  Chrome Mobile                 NDF
# 213427        Web   Desktop (Other)         Chrome                 NDF
# 213428    Android     Android Phone      -unknown-                 NDF
# 213429        iOS            iPhone      -unknown-                 NDF
# 213430        Web       Mac Desktop         Chrome                 NDF
# 213431        Web   Windows Desktop        Firefox                 NDF
# 213432        Web       Mac Desktop         Safari                 NDF
# 213433        Web              iPad  Mobile Safari                 NDF
# 213434        Web       Mac Desktop         Chrome                 NDF
# 213435        Web   Windows Desktop         Chrome                 NDF
# 213436        iOS            iPhone      -unknown-                 NDF
# 213437    Android    Android Tablet      -unknown-                 NDF
# 213438        iOS            iPhone      -unknown-                 NDF
# 213439        Web   Windows Desktop        Firefox                  US
# 213440        iOS            iPhone  Mobile Safari                 NDF
# 213441        Web       Mac Desktop         Chrome                  ES
# 213442        Web       Mac Desktop         Chrome                 NDF
# 213443        Web       Mac Desktop         Safari                  US
# 213444        Web   Windows Desktop         Chrome                 NDF
# 213445        Web   Windows Desktop             IE                  US
# 213446        Web       Mac Desktop         Safari                 NDF
# 213447        Web   Windows Desktop         Chrome                 NDF
# 213448        Web       Mac Desktop        Firefox                 NDF
# 213449        iOS            iPhone  Mobile Safari                 NDF
# 213450        iOS            iPhone      -unknown-                 NDF
#
# [213451 rows x 16 columns]

# %% [markdown]
# ### Remove users with 'No Destination Found'
# We're interested in predicting first destinations, not whether or not they have booked yet.

# %%
users.country_destination.value_counts()
# Out:
# NDF      124543
# US        62376
# other     10094
# FR         5023
# IT         2835
# GB         2324
# ES         2249
# CA         1428
# DE         1061
# NL          762
# AU          539
# PT          217
# Name: country_destination, dtype: int64

# %%
users = users[users.country_destination != 'NDF']

# %%
users.country_destination.value_counts()
# Out:
# US       62376
# other    10094
# FR        5023
# IT        2835
# GB        2324
# ES        2249
# CA        1428
# DE        1061
# NL         762
# AU         539
# PT         217
# Name: country_destination, dtype: int64

# %%
sessions.device_type.value_counts()
# Out:
# Mac Desktop                         3594286
# Windows Desktop                     2658539
# iPhone                              2105031
# Android Phone                        839637
# iPad Tablet                          683414
# Android App Unknown Phone/Tablet     273652
# -unknown-                            211279
# Tablet                               139886
# Linux Desktop                         28373
# Chromebook                            22348
# iPodtouch                              8198
# Windows Phone                          2047
# Blackberry                              979
# Opera Phone                              68
# Name: device_type, dtype: int64

# %%
users
# Out:
#                 id date_account_created timestamp_first_active  \
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# 5       osr2jwljor           2010-01-01    2010-01-01 21:56:19
# 6       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 7       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# 8       a1vcnhxeij           2010-01-04    2010-01-04 00:42:11
# 9       6uh8zyj2gn           2010-01-04    2010-01-04 02:37:58
# 10      yuuqmid2rp           2010-01-04    2010-01-04 19:42:51
# 12      k6np330cm1           2010-01-05    2010-01-05 06:08:59
# 15      v4d5rl22px           2010-01-07    2010-01-07 20:45:55
# 17      frhre329au           2010-01-07    2010-01-07 22:46:25
# 19      gdka1q5ktd           2010-01-10    2010-01-10 01:08:17
# 20      qdubonn3uk           2010-01-10    2010-01-10 15:21:20
# 21      qsibmuz9sx           2010-01-10    2010-01-10 22:09:41
# 22      80f7dwscrn           2010-01-11    2010-01-11 03:14:38
# 25      al8bcetz0g           2010-01-12    2010-01-12 13:14:44
# 27      hfrl5gle36           2010-01-12    2010-01-12 20:59:49
# 28      tp6x3md0n4           2010-01-13    2010-01-13 04:46:50
# 29      hql77nu2lk           2010-01-13    2010-01-13 06:43:33
# 30      cheova4spt           2010-01-14    2010-01-14 02:52:57
# 36      7my0vrljxc           2010-01-15    2010-01-15 22:19:29
# 41      k15j7mbny0           2010-01-19    2010-01-19 01:36:16
# 44      g3z67e37mb           2010-12-01    2010-01-23 09:05:23
# 45      g1q6caq452           2010-01-23    2010-01-23 20:15:40
# 46      f6mzhb4wbc           2010-01-24    2010-01-24 00:23:35
# 47      ngai8kt2yi           2010-01-24    2010-01-24 02:00:49
# 49      byozd991xf           2010-01-24    2010-01-24 23:29:38
# 51      rcx09dn2je           2010-01-25    2010-01-25 20:31:43
# 52      ae59m0iqsx           2010-01-25    2010-01-25 23:22:46
# ...            ...                  ...                    ...
# 213358  auafpy23gk           2014-06-30    2014-06-30 21:27:24
# 213360  g6sulrjk7c           2014-06-30    2014-06-30 21:36:50
# 213369  q7s9qir6xu           2014-06-30    2014-06-30 21:53:48
# 213370  d339w9196p           2014-06-30    2014-06-30 21:55:17
# 213371  5ljgd6ldv8           2014-06-30    2014-06-30 21:57:42
# 213372  0co6s86hgb           2014-06-30    2014-06-30 21:59:47
# 213373  67jxj3h7uf           2014-06-30    2014-06-30 22:01:36
# 213376  i1lzm2k3wr           2014-06-30    2014-06-30 22:02:18
# 213378  nhtc9mxlp7           2014-06-30    2014-06-30 22:03:26
# 213384  bzcqek3k51           2014-06-30    2014-06-30 22:11:15
# 213385  3yew808eqp           2014-06-30    2014-06-30 22:15:22
# 213388  gedoe2zmrj           2014-06-30    2014-06-30 22:22:00
# 213390  c999p94qui           2014-06-30    2014-06-30 22:22:53
# 213398  lc6apdi0hc           2014-06-30    2014-06-30 22:37:31
# 213400  x17avasiuk           2014-06-30    2014-06-30 22:39:43
# 213401  xif0n17eof           2014-06-30    2014-06-30 22:40:49
# 213402  jfcwjhkmtv           2014-06-30    2014-06-30 22:41:08
# 213404  e5ysdcsb2v           2014-06-30    2014-06-30 22:43:36
# 213405  5q5k8aov71           2014-06-30    2014-06-30 22:44:52
# 213406  x3m80xzv0h           2014-06-30    2014-06-30 22:45:40
# 213407  iu1abga5nx           2014-06-30    2014-06-30 22:46:35
# 213408  l8tltghomx           2014-06-30    2014-06-30 22:46:54
# 213409  git9gx54o9           2014-06-30    2014-06-30 22:48:02
# 213410  ezuin5g4lu           2014-06-30    2014-06-30 22:48:32
# 213412  a1rvlsdijt           2014-06-30    2014-06-30 22:51:57
# 213415  7plqriggxp           2014-06-30    2014-06-30 23:01:36
# 213439  msucfwmlzc           2014-06-30    2014-06-30 23:47:29
# 213441  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 213443  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 213445  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# 30             2010-01-24  -unknown-  42.0         basic            0
# 36             2010-01-15     FEMALE  31.0         basic            0
# 41             2010-01-21     FEMALE  30.0         basic            0
# 44             2010-12-03  -unknown-   NaN         basic            0
# 45             2010-01-27     FEMALE  44.0         basic            0
# 46             2010-02-25  -unknown-   NaN         basic            0
# 47             2010-01-24  -unknown-   NaN         basic            0
# 49             2010-01-25  -unknown-  34.0         basic            0
# 51             2010-01-26  -unknown-   NaN         basic            0
# 52             2010-01-26  -unknown-  33.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213358         2014-07-04     FEMALE  29.0         basic            0
# 213360         2015-02-27       MALE  33.0      facebook            0
# 213369         2014-06-30  -unknown-   NaN         basic            0
# 213370         2014-07-01       MALE  27.0         basic            0
# 213371         2014-07-02  -unknown-   NaN         basic            0
# 213372         2015-04-13       MALE  41.0      facebook            0
# 213373         2014-07-01  -unknown-   NaN         basic            0
# 213376         2014-06-30  -unknown-   NaN         basic            0
# 213378         2014-07-04     FEMALE  38.0         basic            0
# 213384         2015-01-06       MALE  22.0         basic           25
# 213385         2014-11-22     FEMALE  39.0         basic           25
# 213388         2015-03-01     FEMALE  30.0         basic            0
# 213390         2014-07-08     FEMALE  30.0         basic            0
# 213398         2014-07-01  -unknown-  39.0         basic            0
# 213400         2014-08-04       MALE  53.0         basic           23
# 213401         2014-07-15  -unknown-  45.0         basic            0
# 213402         2015-04-14       MALE  32.0      facebook            0
# 213404         2014-07-01  -unknown-   NaN         basic            0
# 213405         2015-01-15  -unknown-  23.0         basic            0
# 213406         2014-07-01  -unknown-  35.0         basic            0
# 213407         2014-06-30     FEMALE  21.0      facebook            0
# 213408         2014-07-08       MALE  69.0         basic           23
# 213409         2014-07-12     FEMALE  28.0      facebook            0
# 213410         2015-01-27  -unknown-  33.0         basic            0
# 213412         2015-01-23     FEMALE  50.0         basic            0
# 213415         2014-06-30  -unknown-  55.0         basic            0
# 213439         2015-03-16       MALE  43.0         basic            0
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# 7            en            direct             direct                     omg
# 8            en             other         craigslist               untracked
# 9            en             other         craigslist                     omg
# 10           en             other         craigslist               untracked
# 12           en            direct             direct                     NaN
# 15           en            direct             direct               untracked
# 17           en             other         craigslist                     NaN
# 19           en            direct             direct               untracked
# 20           en            direct             direct                     NaN
# 21           en            direct             direct                  linked
# 22           en               seo             google               untracked
# 25           en             other         craigslist               untracked
# 27           en             other         craigslist               untracked
# 28           en            direct             direct                     NaN
# 29           en            direct             direct               untracked
# 30           en             other         craigslist               untracked
# 36           en            direct             direct                  linked
# 41           en            direct             direct               untracked
# 44           en            direct             direct                     NaN
# 45           en             other         craigslist               untracked
# 46           en            direct             direct               untracked
# 47           en             other         craigslist                     NaN
# 49           en             other         craigslist                     NaN
# 51           en            direct             direct               untracked
# 52           en             other         craigslist               untracked
# ...         ...               ...                ...                     ...
# 213358       en            direct             direct               untracked
# 213360       en            direct             direct               untracked
# 213369       en            direct             direct               untracked
# 213370       en         sem-brand             google                     omg
# 213371       en            direct             direct               untracked
# 213372       en             other          padmapper                     omg
# 213373       en     sem-non-brand             google                     omg
# 213376       en            direct             direct               untracked
# 213378       en         sem-brand             google                     omg
# 213384       en            direct             direct               untracked
# 213385       en            direct             direct                  linked
# 213388       en            direct             direct               untracked
# 213390       en            direct             direct                  linked
# 213398       en            direct             direct               untracked
# 213400       en            direct             direct               untracked
# 213401       en         sem-brand             google                     omg
# 213402       en         sem-brand             google                     omg
# 213404       en            direct             direct                  linked
# 213405       en            direct             direct               untracked
# 213406       en         sem-brand             google                  linked
# 213407       en         sem-brand             google                     omg
# 213408       en            direct             direct               untracked
# 213409       en            direct             direct               untracked
# 213410       en         sem-brand             google                     omg
# 213412       en         sem-brand             google                     omg
# 213415       en         sem-brand             google                     omg
# 213439       en            direct             direct               untracked
# 213441       en            direct             direct                  linked
# 213443       en         sem-brand             google                  linked
# 213445       en         sem-brand             google                     omg
#
#        signup_app first_device_type  first_browser country_destination
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 12            Web     Other/Unknown      -unknown-                  FR
# 15            Web   Windows Desktop         Chrome                  CA
# 17            Web     Other/Unknown      -unknown-                  US
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 25            Web       Mac Desktop         Chrome                  FR
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# 30            Web       Mac Desktop        Firefox                  FR
# 36            Web       Mac Desktop         Safari                  US
# 41            Web       Mac Desktop         Chrome                  US
# 44            Web     Other/Unknown      -unknown-                  GB
# 45            Web   Windows Desktop             IE                  US
# 46            Web       Mac Desktop         Safari                  ES
# 47            Web     Other/Unknown      -unknown-                  US
# 49            Web     Other/Unknown      -unknown-                  US
# 51            Web       Mac Desktop         Safari                  US
# 52            Web              iPad  Mobile Safari                  US
# ...           ...               ...            ...                 ...
# 213358        Web       Mac Desktop        Firefox                  US
# 213360        Web       Mac Desktop         Chrome                  US
# 213369        Web   Windows Desktop         Chrome                  ES
# 213370        Web   Windows Desktop         Chrome                  US
# 213371        Web       Mac Desktop         Chrome                  NL
# 213372        Web       Mac Desktop         Safari                  GB
# 213373        Web       Mac Desktop        Firefox                  US
# 213376        Web            iPhone  Mobile Safari                  US
# 213378        Web       Mac Desktop         Safari                  US
# 213384        iOS            iPhone  Mobile Safari                  US
# 213385        iOS            iPhone  Mobile Safari                  US
# 213388        Web       Mac Desktop         Chrome                  IT
# 213390        Web       Mac Desktop         Chrome                  AU
# 213398        Web            iPhone  Mobile Safari                  US
# 213400    Android     Other/Unknown      -unknown-               other
# 213401        Web       Mac Desktop        Firefox                  FR
# 213402        Web   Windows Desktop         Chrome                  US
# 213404        Web       Mac Desktop         Chrome               other
# 213405        Web       Mac Desktop         Safari                  US
# 213406        Web       Mac Desktop         Chrome                  US
# 213407        Web              iPad  Mobile Safari                  ES
# 213408    Android     Android Phone      -unknown-                  US
# 213409        Web   Windows Desktop        Firefox                  US
# 213410        Web   Windows Desktop         Chrome                  US
# 213412        Web   Windows Desktop         Chrome                  US
# 213415        Web    Android Tablet             IE                  FR
# 213439        Web   Windows Desktop        Firefox                  US
# 213441        Web       Mac Desktop         Chrome                  ES
# 213443        Web       Mac Desktop         Safari                  US
# 213445        Web   Windows Desktop             IE                  US
#
# [88908 rows x 16 columns]

# %% [markdown]
# ## Load into PostgreSQL

# %%
from sqlalchemy import create_engine
cnx = create_engine('postgresql://emilygeller:p@54.173.47.58:5432/emilygeller')
# Out:
# /Users/emilygeller/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#countries.to_sql(name = 'countries', con = cnx, if_exists = 'replace', index = False)
#sessions.to_sql(name = 'sessions', con=  cnx, if_exists = 'replace', index = False)
#users.to_sql(name = 'users', con = cnx, if_exists = 'replace', index = False)
#age_gender_bkts.to_sql(name = 'age_gender_bkts', con = cnx, if_exists = 'replace', index = False)

# %%
sessions = sessions[sessions.user_id.isnull()==False]

# %%
from tqdm import tqdm

# %%
#batch_size = 1000
#sessions_len = sessions.shape[0]
#for i in tqdm(range(sessions_len//batch_size)):
#    print('-----------')
#    print(i*batch_size, 'to', (i+1)*batch_size-1)
#    print('-----------')
#    sessions.iloc[i*batch_size:(i+1)*batch_size-1,:].to_sql(name = 'sessions', con = cnx, if_exists = 'append', index = False)
#    cursor = (i+1)*batch_size-1
#    print('batch done')
#
#sessions.iloc[cursor:sessions_len,:].to_sql(name = 'sessions', con = cnx, if_exists = 'append', index = False)
#print('done!')

# %%
sessions.shape[0]
# Out:
# 10533241

# %%
sessions.to_csv('sessions_cleaned.csv')

# %%
users.to_csv('users_cleaned.csv')

# %%
sessions.dtypes
# Out:
# user_id           object
# action            object
# action_type       object
# action_detail     object
# device_type       object
# secs_elapsed     float64
# dtype: object

# %% [markdown]
# At this point I exported my dataframes to CSV, converted them to TAR, sent them to my AWS instance and created a PostgreSQL database with them. I tried to do it all from the Jupyter notebook but it was going to take 300 hours for one of the tables!

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6711f799eb91> in <module>()
# ----> 1 users
#
# NameError: name 'users' is not defined

# %%
pd.read_sql('select * from users limit 5;', cnx)
# Out:
#    id     user_id date_account_created timestamp_first_active  gender   age  \
# 0   2  4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47  FEMALE  56.0
# 1   3  bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29  FEMALE  42.0
# 2   4  87mebub9p4           2010-09-14    2009-12-08 06:11:05    None  41.0
# 3   5  osr2jwljor           2010-01-01    2010-01-01 21:56:19    None   NaN
# 4   6  lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58  FEMALE  46.0
#
#   signup_method signup_flow language affiliate_channel affiliate_provider  \
# 0         basic           3       en            direct             direct
# 1      facebook           0       en            direct             direct
# 2         basic           0       en            direct             direct
# 3         basic           0       en             other              other
# 4         basic           0       en             other         craigslist
#
#   first_affiliate_tracked signup_app first_device_type first_browser  \
# 0                    None        Web   Windows Desktop            IE
# 1                    None        Web       Mac Desktop       Firefox
# 2                    None        Web       Mac Desktop        Chrome
# 3                     omg        Web       Mac Desktop        Chrome
# 4                    None        Web       Mac Desktop        Safari
#
#   country_destination
# 0                  US
# 1               other
# 2                  US
# 3                  US
# 4                  US

# %%
pd.read_sql('select * from sessions limit 5;',cnx)
# Out:
#    id     user_id          action action_type        action_detail  \
# 0   0  d1mm9tcy42          lookup        None                 None
# 1   1  d1mm9tcy42  search_results       click  view_search_results
# 2   2  d1mm9tcy42          lookup        None                 None
# 3   3  d1mm9tcy42  search_results       click  view_search_results
# 4   4  d1mm9tcy42          lookup        None                 None
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %% [markdown]
# ## Other

# %%
train_users.country_destination.value_counts()
# Out:
# NDF      124543
# US        62376
# other     10094
# FR         5023
# IT         2835
# GB         2324
# ES         2249
# CA         1428
# DE         1061
# NL          762
# AU          539
# PT          217
# Name: country_destination, dtype: int64

# %%
cntry = dmatrix("country_destination", age_gender_bkts, return_type = 'dataframe')

# %%
age_gender_bkts = age_gender_bkts.join(cntry)

# %% [markdown]
# #### Sessions Actions Exploration

# %%
def transform_action
# take string, return string if value count > amount.. return other if <

# %%
sessions.action_type.value_counts()
# Out:
# view                3560902
# data                2103770
# click               1996183
# -unknown-           1031170
# submit               623357
# message_post          87103
# partner_callback      19132
# booking_request       18773
# modify                 1139
# booking_response          4
# Name: action_type, dtype: int64

# %%
sessions.action.value_counts()#['active']
# Out:
# show                           2768278
# index                           843699
# search_results                  725226
# personalize                     706824
# search                          536057
# ajax_refresh_subtotal           487744
# update                          365130
# similar_listings                364624
# social_connections              339000
# reviews                         320591
# active                          188036
# similar_listings_v2             168788
# lookup                          162041
# create                          155887
# dashboard                       152952
# header_userpic                  141830
# collections                     124417
# edit                            109083
# campaigns                       105028
# track_page_view                  81117
# unavailabilities                 78317
# qt2                              64651
# notifications                    59392
# confirm_email                    58726
# requested                        57034
# identity                         53631
# ajax_check_dates                 52517
# show_personalize                 50434
# ask_question                     44063
# listings                         43656
#                                 ...
# use_mobile_site                      2
# rest-of-world                        2
# envoy_bank_details_redirect          2
# reset_calendar                       2
# refund_guest_cancellation            2
# accept_decline                       2
# stpcv                                2
# friend_listing                       2
# views_campaign                       2
# unsubscribe                          2
# preapproval                          2
# views_campaign_rules                 2
# report                               2
# recommendation_page                  2
# sandy                                2
# acculynk_bin_check_failed            1
# deactivate                           1
# deauthorize                          1
# reactivate                           1
# plaxo_cb                             1
# deactivated                          1
# nyan                                 1
# events                               1
# wishlists                            1
# set_minimum_payout_amount            1
# desks                                1
# sldf                                 1
# update_message                       1
# revert_to_admin                      1
# host_cancel                          1
# Name: action, Length: 359, dtype: int64
